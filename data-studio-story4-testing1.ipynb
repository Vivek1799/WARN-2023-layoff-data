# %%
import requests
from bs4 import BeautifulSoup

# %%
from playwright.async_api import async_playwright

# %%
playwright = await async_playwright().start()

# %%
browser = await playwright.chromium.launch(headless = False)

# %%
browser.new_page()

# %%
page = await browser.new_page()

# %%
await page.goto("https://dol.ny.gov/warn-notices")

# %%
#the code below downloads the pdf when the link is first given.
# def download_pdf(url, output_file):
#     response = requests.get(url)

#     if response.status_code == 200:
#         with open(output_file, 'wb') as file:
#             file.write(response.content)
#     else:
#         print(f"Failed to download the file. Status code: {response.status_code}")

# pdf_url = "https://dol.ny.gov/system/files/documents/2023/04/warn-roses-confections-mohawk-valley-2022-0086-4-7-2023-amendment_0.pdf"
# output_path = "test2.pdf"

# download_pdf(pdf_url, output_path)

# %%
import requests
url = "https://dol.ny.gov/warn-notices"
response = requests.get(url)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# ...

# %%
link = soup.find('td').find('a')

# %%
all = link['href']

# %%
all
# Out:
# '/warn-roses-confections-mohawk-valley-2022-0086-4-7-2023-amendment'

# %%
# Find the 'a' tag
a_tag = soup.find('a')

# Extract the 'href' attribute value
link = a_tag['href']

# %%
print (link)
# Out:
# #main-content

# %%
html_string = '<td data-th="Company Name"><a href="/warn-bg-salon-yoshiko-nyc-2022-0127-4-7-2023" target="_blank">BG Salon, LLC - Salon Yoshiko - New York City Region</a></td>" target="_blank">Roses Confections, LP - Mohawk Valley Region</a></td>'
soup = BeautifulSoup(html_string, 'html.parser')

# Find the 'a' tag
a_tag = soup.find('a')

# Extract the 'href' attribute value
link = a_tag['href']

print(link)
# Out:
# /warn-bg-salon-yoshiko-nyc-2022-0127-4-7-2023

# %%
<td data-th="Company Name"><a href="/warn-roses-confections-mohawk-valley-2022-0086-4-7-2023-amendment" target="_blank">Roses Confections, LP - Mohawk Valley Region</a></td>

# %%
https://dol.ny.gov//warn-bg-salon-yoshiko-nyc-2022-0127-4-7-2023

# %%
# Find all 'td' tags with 'data-th' attribute
td_tags = soup.find_all('td', attrs={'data-th': True})

# for td_tag in td_tags:
#     # Find 'a' tag inside the 'td' tag
#     a_tag = td_tag.find('a')
    
#     # Check if 'a' tag exists
#     if a_tag:
#         # Extract the 'href' attribute value and print it
#         linkS = a_tag['href']
#         print(linkS)

# %%
td_tags
# Out:
# []

# %%
tags = soup.find_all('td.data-t')

for tag in tags:
    a_tag = tags.find('a')
    m = a_tag['href']
    print(m)

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [50], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
tags = soup.find_all('td', class_='data-t')

for tag in tags:
    a_tag = tag.find('a')
    if a_tag is not None:
        m = a_tag['href']
        print(m)

# %%
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [52], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
m = ''

tags = soup.find_all('td', class_='data-t')

for tag in tags:
    a_tag = tag.find('a')
    if a_tag is not None:
        m = a_tag['href']

if m:
    print(m)

# %%
m
# Out:
# ''
